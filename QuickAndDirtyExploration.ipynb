# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pyodbc
import plotly.express as px
import plotly.io as pio
pio.renderers.default = "notebook"

import helper
import dataloader

# %%
query = """
        SELECT
            MarketName, 
            Booking, 
            DateOfBirth, 
            DateBooked, 
            WeekBooked, 
            isnull(ws.SortOrder,13) as SortOrder,
            ProgramDuration,
            DateCaxed, 
            FiscalYear, 
            ProgramStartDate, 
            SalesRepID, 
            u.Name as SalesRepName, 
            OriginalRanking, 
            MethodOfCreation,
            hasBooked =1,
            hasCaxed = case when DateCaxed is null then 0 else 1 end
        from sales s
        join Users u on u.User_id = s.SalesRepID
        left join WeekSort ws on ws.WeekNum = right(s.WeekBooked,2)
        """

# %%
df_original = helper.get_dataframe_from_sqlserver_query(query=query)
# Out:
# /Users/ganesh/Documents/ImportantWork/CleanRepo/BookingSales/helper.py:82: UserWarning:
#
# pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.

# %%
df_original.head()
# Out:
#     MarketName    Booking DateOfBirth          DateBooked  WeekBooked  \
# 0        China  CN_198974  2004-05-06 2020-06-24 21:23:37        2026
# 1        Japan  JP_180044  2004-12-15 2020-07-29 20:26:36        2031
# 2  South Korea  KR_129434  2004-01-06 2020-06-24 18:52:08        2026
# 3      Vietnam  VN_133204  2004-06-06 2020-07-29 18:04:08        2031
# 4      Vietnam  VN_133206  2004-01-31 2020-07-29 18:18:49        2031
#
#    SortOrder  ProgramDuration DateCaxed  FiscalYear ProgramStartDate  \
# 0         39              9.0       NaT        2020       2020-06-29
# 1         44              4.0       NaT        2020       2020-08-03
# 2         39              9.0       NaT        2020       2020-06-29
# 3         44              4.0       NaT        2020       2020-08-03
# 4         44              4.0       NaT        2020       2020-08-03
#
#    SalesRepID      SalesRepName  OriginalRanking MethodOfCreation  hasBooked  \
# 0         892  Malvina Belgrano                6          Website          1
# 1         892  Malvina Belgrano                1    EnteredByUser          1
# 2         892  Malvina Belgrano                1    EnteredByUser          1
# 3         892  Malvina Belgrano                4    EnteredByUser          1
# 4         892  Malvina Belgrano                4    EnteredByUser          1
#
#    hasCaxed
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
df_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34705 entries, 0 to 34704
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   MarketName        34705 non-null  object
#  1   Booking           34705 non-null  object
#  2   DateOfBirth       34703 non-null  datetime64[ns]
#  3   DateBooked        34705 non-null  datetime64[ns]
#  4   WeekBooked        34705 non-null  int64
#  5   SortOrder         34705 non-null  int64
#  6   ProgramDuration   34704 non-null  float64
#  7   DateCaxed         10320 non-null  datetime64[ns]
#  8   FiscalYear        34705 non-null  int64
#  9   ProgramStartDate  34601 non-null  datetime64[ns]
#  10  SalesRepID        34705 non-null  int64
#  11  SalesRepName      34705 non-null  object
#  12  OriginalRanking   34705 non-null  int64
#  13  MethodOfCreation  34701 non-null  object
#  14  hasBooked         34705 non-null  int64
#  15  hasCaxed          34705 non-null  int64
# dtypes: datetime64[ns](4), float64(1), int64(7), object(4)
# memory usage: 4.2+ MB

# %% [markdown]
# ### Pre-Processing

# %%
df_bookings = (df_original
               .assign(
                       ProgramDuration = lambda _df: _df['ProgramDuration'].fillna(_df['ProgramDuration'].median()).astype('int16'),
                       DaysToCAX = lambda _df: (_df['DateCaxed'] - _df['DateBooked']).dt.days.astype('Int64'),
                       WeekNum = lambda _df: _df['WeekBooked'].astype('str').str[-2:].astype('int8'),
                       hasCaxed = lambda _df: _df['hasCaxed'].astype('bool'),
                       hasBooked = lambda _df: _df['hasBooked'].astype('bool'),
                )
               .rename(columns={'Booking': 'BookingId'})
)

# %%
df_bookings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34705 entries, 0 to 34704
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   MarketName        34705 non-null  object
#  1   BookingId         34705 non-null  object
#  2   DateOfBirth       34703 non-null  datetime64[ns]
#  3   DateBooked        34705 non-null  datetime64[ns]
#  4   WeekBooked        34705 non-null  int64
#  5   SortOrder         34705 non-null  int64
#  6   ProgramDuration   34705 non-null  int16
#  7   DateCaxed         10320 non-null  datetime64[ns]
#  8   FiscalYear        34705 non-null  int64
#  9   ProgramStartDate  34601 non-null  datetime64[ns]
#  10  SalesRepID        34705 non-null  int64
#  11  SalesRepName      34705 non-null  object
#  12  OriginalRanking   34705 non-null  int64
#  13  MethodOfCreation  34701 non-null  object
#  14  hasBooked         34705 non-null  bool
#  15  hasCaxed          34705 non-null  bool
#  16  DaysToCAX         10320 non-null  Int64
#  17  WeekNum           34705 non-null  int8
# dtypes: Int64(1), bool(2), datetime64[ns](4), int16(1), int64(5), int8(1), object(4)
# memory usage: 3.9+ MB

# %%
data = df_bookings.groupby(['MarketName','SalesRepName'])[['BookingId', 'ProgramDuration']].agg({'BookingId':'count', 'ProgramDuration':'sum'}).reset_index()
fig = px.scatter(data, x="BookingId", y="ProgramDuration", color="MarketName", opacity= 0.8, size='ProgramDuration')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 data = df_bookings.groupby(['MarketName','SalesRepName'])[['BookingId', 'ProgramDuration']].agg({'BookingId':'count', 'ProgramDuration':'sum'}).reset_index()
#       2 fig = px.scatter(data, x="BookingId", y="ProgramDuration", color="MarketName", opacity= 0.8, size='ProgramDuration')
#       3 fig.show()
#
# NameError: name 'df_bookings' is not defined

# %%
df_bookings.columns
# Out:
# Index(['MarketName', 'BookingId', 'DateOfBirth', 'DateBooked', 'WeekBooked',
#        'SortOrder', 'ProgramDuration', 'DateCaxed', 'FiscalYear',
#        'ProgramStartDate', 'SalesRepID', 'SalesRepName', 'OriginalRanking',
#        'MethodOfCreation', 'hasBooked', 'hasCaxed', 'DaysToCAX', 'WeekNum'],
#       dtype='object')

# %%
df_bookings[df_bookings['DateCaxed'].isna()]
# Out:
#         MarketName  BookingId DateOfBirth          DateBooked  WeekBooked  \
# 0            China  CN_198974  2004-05-06 2020-06-24 21:23:37        2026
# 1            Japan  JP_180044  2004-12-15 2020-07-29 20:26:36        2031
# 2      South Korea  KR_129434  2004-01-06 2020-06-24 18:52:08        2026
# 3          Vietnam  VN_133204  2004-06-06 2020-07-29 18:04:08        2031
# 4          Vietnam  VN_133206  2004-01-31 2020-07-29 18:18:49        2031
# ...            ...        ...         ...                 ...         ...
# 34700    Hong Kong  HK_137037  2004-09-12 2021-09-01 17:08:59        2135
# 34701    Hong Kong  HK_137039  2004-04-14 2021-09-04 17:36:27        2136
# 34702    Hong Kong  HK_137016  2003-12-14 2021-08-03 17:32:04        2131
# 34703    Hong Kong  HK_137046  2004-08-22 2021-09-18 18:10:07        2138
# 34704    Hong Kong  HK_137045  2004-08-22 2021-09-18 17:49:36        2138
#
#        SortOrder  ProgramDuration DateCaxed  FiscalYear ProgramStartDate  \
# 0             39                9       NaT        2020       2020-06-29
# 1             44                4       NaT        2020       2020-08-03
# 2             39                9       NaT        2020       2020-06-29
# 3             44                4       NaT        2020       2020-08-03
# 4             44                4       NaT        2020       2020-08-03
# ...          ...              ...       ...         ...              ...
# 34700         48               35       NaT        2021       2022-09-19
# 34701         49               39       NaT        2021       2021-09-20
# 34702         44               50       NaT        2021       2021-09-20
# 34703         51               77       NaT        2021       2022-09-19
# 34704         51               77       NaT        2021       2022-09-19
#
#        SalesRepID      SalesRepName  OriginalRanking MethodOfCreation  \
# 0             892  Malvina Belgrano                6          Website
# 1             892  Malvina Belgrano                1    EnteredByUser
# 2             892  Malvina Belgrano                1    EnteredByUser
# 3             892  Malvina Belgrano                4    EnteredByUser
# 4             892  Malvina Belgrano                4    EnteredByUser
# ...           ...               ...              ...              ...
# 34700       69130       Christy Tam                1    EnteredByUser
# 34701       69130       Christy Tam                8          Website
# 34702       69130       Christy Tam                6          Website
# 34703       69300      Shirley Ling                5          Website
# 34704       69300      Shirley Ling                5          Website
#
#        hasBooked  hasCaxed  DaysToCAX  WeekNum
# 0           True     False       <NA>       26
# 1           True     False       <NA>       31
# 2           True     False       <NA>       26
# 3           True     False       <NA>       31
# 4           True     False       <NA>       31
# ...          ...       ...        ...      ...
# 34700       True     False       <NA>       35
# 34701       True     False       <NA>       36
# 34702       True     False       <NA>       31
# 34703       True     False       <NA>       38
# 34704       True     False       <NA>       38
#
# [24385 rows x 18 columns]

# %%
df_bookings.columns
# Out:
# Index(['MarketName', 'BookingId', 'DateOfBirth', 'DateBooked', 'WeekBooked',
#        'SortOrder', 'ProgramDuration', 'DateCaxed', 'FiscalYear',
#        'ProgramStartDate', 'SalesRepID', 'SalesRepName', 'OriginalRanking',
#        'MethodOfCreation', 'hasBooked', 'hasCaxed', 'DaysToCAX', 'WeekNum'],
#       dtype='object')

# %%
df_booked = (df_bookings
    .rename(columns={'DateBooked': 'MainDate'})
    .assign(
        MainDate = lambda _df: _df['MainDate'].dt.normalize(),
        RankBin = lambda _df: pd.cut(df_bookings['OriginalRanking'], bins = [0,4,5,10], labels=['1-4', '5', '6-10'],),
    )
    .drop(['OriginalRanking'], axis = 1)
    
)

# %%
df_booked= pd.get_dummies(df_booked, columns=['MethodOfCreation', 'RankBin'], prefix = {'MethodOfCreation':'', 'RankBin':'Rank'}, prefix_sep = '')

# %%
df_booked
# Out:
#         MarketName  BookingId DateOfBirth   MainDate  WeekBooked  SortOrder  \
# 0            China  CN_198974  2004-05-06 2020-06-24        2026         39
# 1            Japan  JP_180044  2004-12-15 2020-07-29        2031         44
# 2      South Korea  KR_129434  2004-01-06 2020-06-24        2026         39
# 3          Vietnam  VN_133204  2004-06-06 2020-07-29        2031         44
# 4          Vietnam  VN_133206  2004-01-31 2020-07-29        2031         44
# ...            ...        ...         ...        ...         ...        ...
# 34700    Hong Kong  HK_137037  2004-09-12 2021-09-01        2135         48
# 34701    Hong Kong  HK_137039  2004-04-14 2021-09-04        2136         49
# 34702    Hong Kong  HK_137016  2003-12-14 2021-08-03        2131         44
# 34703    Hong Kong  HK_137046  2004-08-22 2021-09-18        2138         51
# 34704    Hong Kong  HK_137045  2004-08-22 2021-09-18        2138         51
#
#        ProgramDuration DateCaxed  FiscalYear ProgramStartDate  ...  hasBooked  \
# 0                    9       NaT        2020       2020-06-29  ...       True
# 1                    4       NaT        2020       2020-08-03  ...       True
# 2                    9       NaT        2020       2020-06-29  ...       True
# 3                    4       NaT        2020       2020-08-03  ...       True
# 4                    4       NaT        2020       2020-08-03  ...       True
# ...                ...       ...         ...              ...  ...        ...
# 34700               35       NaT        2021       2022-09-19  ...       True
# 34701               39       NaT        2021       2021-09-20  ...       True
# 34702               50       NaT        2021       2021-09-20  ...       True
# 34703               77       NaT        2021       2022-09-19  ...       True
# 34704               77       NaT        2021       2022-09-19  ...       True
#
#       hasCaxed  DaysToCAX  WeekNum  EnteredByUser  Excel Import  Website  \
# 0        False       <NA>       26              0             0        1
# 1        False       <NA>       31              1             0        0
# 2        False       <NA>       26              1             0        0
# 3        False       <NA>       31              1             0        0
# 4        False       <NA>       31              1             0        0
# ...        ...        ...      ...            ...           ...      ...
# 34700    False       <NA>       35              1             0        0
# 34701    False       <NA>       36              0             0        1
# 34702    False       <NA>       31              0             0        1
# 34703    False       <NA>       38              0             0        1
# 34704    False       <NA>       38              0             0        1
#
#        Rank1-4  Rank5  Rank6-10
# 0            0      0         1
# 1            1      0         0
# 2            1      0         0
# 3            1      0         0
# 4            1      0         0
# ...        ...    ...       ...
# 34700        1      0         0
# 34701        0      0         1
# 34702        0      0         1
# 34703        0      1         0
# 34704        0      1         0
#
# [34705 rows x 22 columns]

# %%
df_booked = df_booked.groupby(['MainDate', 'MarketName', 'SalesRepID', 'SalesRepName', 'WeekBooked', 'WeekNum',
       'SortOrder','FiscalYear',
       ])[['hasBooked', 'hasCaxed', 'ProgramDuration', 'EnteredByUser', 'Excel Import', 'Website', 'Rank1-4', 'Rank5','Rank6-10']].sum()

# %%
df_booked
# Out:
#                                                                                             hasBooked  \
# MainDate   MarketName  SalesRepID SalesRepName     WeekBooked WeekNum SortOrder FiscalYear
# 2018-09-28 China       1997       Christy Liu      1840       40      1         2019                2
#                        50978      Qian Liu         1840       40      1         2019                1
#                        51158      Bonnie Yin       1840       40      1         2019                2
#                        51244      Cuicui Zhai      1840       40      1         2019                2
#                        53397      Ines Wang        1840       40      1         2019                4
# ...                                                                                               ...
# 2021-09-29 Japan       64660      Maya Ichikawa    2139       39      52        2021                2
#                        67577      Ryoichi Yamamoto 2139       39      52        2021                1
#                        68123      Shu Nozawa       2139       39      52        2021                1
#            South Korea 57612      Eric Park        2139       39      52        2021                1
#                        66705      Yoonjung Cho     2139       39      52        2021                3
#
#                                                                                             hasCaxed  \
# MainDate   MarketName  SalesRepID SalesRepName     WeekBooked WeekNum SortOrder FiscalYear
# 2018-09-28 China       1997       Christy Liu      1840       40      1         2019               2
#                        50978      Qian Liu         1840       40      1         2019               1
#                        51158      Bonnie Yin       1840       40      1         2019               0
#                        51244      Cuicui Zhai      1840       40      1         2019               2
#                        53397      Ines Wang        1840       40      1         2019               3
# ...                                                                                              ...
# 2021-09-29 Japan       64660      Maya Ichikawa    2139       39      52        2021               0
#                        67577      Ryoichi Yamamoto 2139       39      52        2021               0
#                        68123      Shu Nozawa       2139       39      52        2021               0
#            South Korea 57612      Eric Park        2139       39      52        2021               0
#                        66705      Yoonjung Cho     2139       39      52        2021               0
#
#                                                                                             ProgramDuration  \
# MainDate   MarketName  SalesRepID SalesRepName     WeekBooked WeekNum SortOrder FiscalYear
# 2018-09-28 China       1997       Christy Liu      1840       40      1         2019                     18
#                        50978      Qian Liu         1840       40      1         2019                      8
#                        51158      Bonnie Yin       1840       40      1         2019                      5
#                        51244      Cuicui Zhai      1840       40      1         2019                    105
#                        53397      Ines Wang        1840       40      1         2019                     10
# ...                                                                                                     ...
# 2021-09-29 Japan       64660      Maya Ichikawa    2139       39      52        2021                     12
#                        67577      Ryoichi Yamamoto 2139       39      52        2021                      6
#                        68123      Shu Nozawa       2139       39      52        2021                     22
#            South Korea 57612      Eric Park        2139       39      52        2021                     34
#                        66705      Yoonjung Cho     2139       39      52        2021                    124
#
#                                                                                             EnteredByUser  \
# MainDate   MarketName  SalesRepID SalesRepName     WeekBooked WeekNum SortOrder FiscalYear
# 2018-09-28 China       1997       Christy Liu      1840       40      1         2019                    1
#                        50978      Qian Liu         1840       40      1         2019                    1
#                        51158      Bonnie Yin       1840       40      1         2019                    2
#                        51244      Cuicui Zhai      1840       40      1         2019                    2
#                        53397      Ines Wang        1840       40      1         2019                    3
# ...                                                                                                   ...
# 2021-09-29 Japan       64660      Maya Ichikawa    2139       39      52        2021                    1
#                        67577      Ryoichi Yamamoto 2139       39      52        2021                    0
#                        68123      Shu Nozawa       2139       39      52        2021                    1
#            South Korea 57612      Eric Park        2139       39      52        2021                    1
#                        66705      Yoonjung Cho     2139       39      52        2021                    2
#
#                                                                                             Excel Import  \
# MainDate   MarketName  SalesRepID SalesRepName     WeekBooked WeekNum SortOrder FiscalYear
# 2018-09-28 China       1997       Christy Liu      1840       40      1         2019                   0
#                        50978      Qian Liu         1840       40      1         2019                   0
#                        51158      Bonnie Yin       1840       40      1         2019                   0
#                        51244      Cuicui Zhai      1840       40      1         2019                   0
#                        53397      Ines Wang        1840       40      1         2019                   0
# ...                                                                                                  ...
# 2021-09-29 Japan       64660      Maya Ichikawa    2139       39      52        2021                   0
#                        67577      Ryoichi Yamamoto 2139       39      52        2021                   0
#                        68123      Shu Nozawa       2139       39      52        2021                   0
#            South Korea 57612      Eric Park        2139       39      52        2021                   0
#                        66705      Yoonjung Cho     2139       39      52        2021                   0
#
#                                                                                             Website  \
# MainDate   MarketName  SalesRepID SalesRepName     WeekBooked WeekNum SortOrder FiscalYear
# 2018-09-28 China       1997       Christy Liu      1840       40      1         2019              1
#                        50978      Qian Liu         1840       40      1         2019              0
#                        51158      Bonnie Yin       1840       40      1         2019              0
#                        51244      Cuicui Zhai      1840       40      1         2019              0
#                        53397      Ines Wang        1840       40      1         2019              1
# ...                                                                                             ...
# 2021-09-29 Japan       64660      Maya Ichikawa    2139       39      52        2021              1
#                        67577      Ryoichi Yamamoto 2139       39      52        2021              1
#                        68123      Shu Nozawa       2139       39      52        2021              0
#            South Korea 57612      Eric Park        2139       39      52        2021              0
#                        66705      Yoonjung Cho     2139       39      52        2021              1
#
#                                                                                             Rank1-4  \
# MainDate   MarketName  SalesRepID SalesRepName     WeekBooked WeekNum SortOrder FiscalYear
# 2018-09-28 China       1997       Christy Liu      1840       40      1         2019              2
#                        50978      Qian Liu         1840       40      1         2019              1
#                        51158      Bonnie Yin       1840       40      1         2019              2
#                        51244      Cuicui Zhai      1840       40      1         2019              2
#                        53397      Ines Wang        1840       40      1         2019              3
# ...                                                                                             ...
# 2021-09-29 Japan       64660      Maya Ichikawa    2139       39      52        2021              2
#                        67577      Ryoichi Yamamoto 2139       39      52        2021              1
#                        68123      Shu Nozawa       2139       39      52        2021              1
#            South Korea 57612      Eric Park        2139       39      52        2021              1
#                        66705      Yoonjung Cho     2139       39      52        2021              2
#
#                                                                                             Rank5  \
# MainDate   MarketName  SalesRepID SalesRepName     WeekBooked WeekNum SortOrder FiscalYear
# 2018-09-28 China       1997       Christy Liu      1840       40      1         2019            0
#                        50978      Qian Liu         1840       40      1         2019            0
#                        51158      Bonnie Yin       1840       40      1         2019            0
#                        51244      Cuicui Zhai      1840       40      1         2019            0
#                        53397      Ines Wang        1840       40      1         2019            0
# ...                                                                                           ...
# 2021-09-29 Japan       64660      Maya Ichikawa    2139       39      52        2021            0
#                        67577      Ryoichi Yamamoto 2139       39      52        2021            0
#                        68123      Shu Nozawa       2139       39      52        2021            0
#            South Korea 57612      Eric Park        2139       39      52        2021            0
#                        66705      Yoonjung Cho     2139       39      52        2021            1
#
#                                                                                             Rank6-10
# MainDate   MarketName  SalesRepID SalesRepName     WeekBooked WeekNum SortOrder FiscalYear
# 2018-09-28 China       1997       Christy Liu      1840       40      1         2019               0
#                        50978      Qian Liu         1840       40      1         2019               0
#                        51158      Bonnie Yin       1840       40      1         2019               0
#                        51244      Cuicui Zhai      1840       40      1         2019               0
#                        53397      Ines Wang        1840       40      1         2019               1
# ...                                                                                              ...
# 2021-09-29 Japan       64660      Maya Ichikawa    2139       39      52        2021               0
#                        67577      Ryoichi Yamamoto 2139       39      52        2021               0
#                        68123      Shu Nozawa       2139       39      52        2021               0
#            South Korea 57612      Eric Park        2139       39      52        2021               0
#                        66705      Yoonjung Cho     2139       39      52        2021               0
#
# [20112 rows x 9 columns]

# %%
df_booked[['Rank5']].sum()
# Out:
# Rank5    3538
# dtype: int64

# %%
df_caxed = (df_bookings[df_bookings['hasCaxed']==True]
    .rename(columns={'DateBooked': 'MainDate'})
    .assign(
        MainDate = lambda _df: _df['MainDate'].dt.normalize(),
        RankBin = lambda _df: pd.cut(df_bookings['OriginalRanking'], bins = [0,4,5,10], labels=['1-4', '5', '6-10'],),
    )
    .drop(['OriginalRanking'], axis = 1)
    
)

# %%
df_caxed= pd.get_dummies(df_caxed, columns=['MethodOfCreation', 'RankBin'], prefix = {'MethodOfCreation':'', 'RankBin':'Rank'}, prefix_sep = '')

# %%
df_caxed[['Rank5']].sum()
# Out:
# Rank5    951
# dtype: int64

# %%
df_caxed = df_caxed.groupby(['MainDate', 'MarketName', 'SalesRepID', 'SalesRepName', 'WeekBooked', 'WeekNum',
       'SortOrder','FiscalYear',
       ])[['hasBooked', 'hasCaxed', 'ProgramDuration', 'EnteredByUser', 'Excel Import', 'Website', 'Rank1-4', 'Rank5','Rank6-10']].sum()

# %%
df_caxed.drop(['hasBooked', 'hasCaxed'], axis=1, inplace=True)

# %%
df_caxed
# Out:
#                                                                                          ProgramDuration  \
# MainDate   MarketName  SalesRepID SalesRepName  WeekBooked WeekNum SortOrder FiscalYear
# 2018-09-28 China       1997       Christy Liu   1840       40      1         2019                     18
#                        50978      Qian Liu      1840       40      1         2019                      8
#                        51244      Cuicui Zhai   1840       40      1         2019                    105
#                        53397      Ines Wang     1840       40      1         2019                      8
#                        57068      Jeremy Wanghz 1840       40      1         2019                     12
# ...                                                                                                  ...
# 2021-09-23 Japan       64620      Yumi Ono      2138       38      51        2021                     12
#            South Korea 51766      Jimin Kang    2138       38      51        2021                     26
#                        57611      Sunjeong Lee  2138       38      51        2021                     68
# 2021-09-24 China       57957      Doris Han     2139       39      52        2021                     62
#            Taiwan      66282      Nera Huang    2139       39      52        2021                     66
#
#                                                                                          EnteredByUser  \
# MainDate   MarketName  SalesRepID SalesRepName  WeekBooked WeekNum SortOrder FiscalYear
# 2018-09-28 China       1997       Christy Liu   1840       40      1         2019                    1
#                        50978      Qian Liu      1840       40      1         2019                    1
#                        51244      Cuicui Zhai   1840       40      1         2019                    2
#                        53397      Ines Wang     1840       40      1         2019                    2
#                        57068      Jeremy Wanghz 1840       40      1         2019                    0
# ...                                                                                                ...
# 2021-09-23 Japan       64620      Yumi Ono      2138       38      51        2021                    0
#            South Korea 51766      Jimin Kang    2138       38      51        2021                    1
#                        57611      Sunjeong Lee  2138       38      51        2021                    1
# 2021-09-24 China       57957      Doris Han     2139       39      52        2021                    2
#            Taiwan      66282      Nera Huang    2139       39      52        2021                    1
#
#                                                                                          Excel Import  \
# MainDate   MarketName  SalesRepID SalesRepName  WeekBooked WeekNum SortOrder FiscalYear
# 2018-09-28 China       1997       Christy Liu   1840       40      1         2019                   0
#                        50978      Qian Liu      1840       40      1         2019                   0
#                        51244      Cuicui Zhai   1840       40      1         2019                   0
#                        53397      Ines Wang     1840       40      1         2019                   0
#                        57068      Jeremy Wanghz 1840       40      1         2019                   0
# ...                                                                                               ...
# 2021-09-23 Japan       64620      Yumi Ono      2138       38      51        2021                   0
#            South Korea 51766      Jimin Kang    2138       38      51        2021                   0
#                        57611      Sunjeong Lee  2138       38      51        2021                   0
# 2021-09-24 China       57957      Doris Han     2139       39      52        2021                   0
#            Taiwan      66282      Nera Huang    2139       39      52        2021                   0
#
#                                                                                          Website  \
# MainDate   MarketName  SalesRepID SalesRepName  WeekBooked WeekNum SortOrder FiscalYear
# 2018-09-28 China       1997       Christy Liu   1840       40      1         2019              1
#                        50978      Qian Liu      1840       40      1         2019              0
#                        51244      Cuicui Zhai   1840       40      1         2019              0
#                        53397      Ines Wang     1840       40      1         2019              1
#                        57068      Jeremy Wanghz 1840       40      1         2019              1
# ...                                                                                          ...
# 2021-09-23 Japan       64620      Yumi Ono      2138       38      51        2021              1
#            South Korea 51766      Jimin Kang    2138       38      51        2021              0
#                        57611      Sunjeong Lee  2138       38      51        2021              0
# 2021-09-24 China       57957      Doris Han     2139       39      52        2021              0
#            Taiwan      66282      Nera Huang    2139       39      52        2021              0
#
#                                                                                          Rank1-4  \
# MainDate   MarketName  SalesRepID SalesRepName  WeekBooked WeekNum SortOrder FiscalYear
# 2018-09-28 China       1997       Christy Liu   1840       40      1         2019              2
#                        50978      Qian Liu      1840       40      1         2019              1
#                        51244      Cuicui Zhai   1840       40      1         2019              2
#                        53397      Ines Wang     1840       40      1         2019              2
#                        57068      Jeremy Wanghz 1840       40      1         2019              1
# ...                                                                                          ...
# 2021-09-23 Japan       64620      Yumi Ono      2138       38      51        2021              1
#            South Korea 51766      Jimin Kang    2138       38      51        2021              1
#                        57611      Sunjeong Lee  2138       38      51        2021              1
# 2021-09-24 China       57957      Doris Han     2139       39      52        2021              2
#            Taiwan      66282      Nera Huang    2139       39      52        2021              1
#
#                                                                                          Rank5  \
# MainDate   MarketName  SalesRepID SalesRepName  WeekBooked WeekNum SortOrder FiscalYear
# 2018-09-28 China       1997       Christy Liu   1840       40      1         2019            0
#                        50978      Qian Liu      1840       40      1         2019            0
#                        51244      Cuicui Zhai   1840       40      1         2019            0
#                        53397      Ines Wang     1840       40      1         2019            0
#                        57068      Jeremy Wanghz 1840       40      1         2019            0
# ...                                                                                        ...
# 2021-09-23 Japan       64620      Yumi Ono      2138       38      51        2021            0
#            South Korea 51766      Jimin Kang    2138       38      51        2021            0
#                        57611      Sunjeong Lee  2138       38      51        2021            0
# 2021-09-24 China       57957      Doris Han     2139       39      52        2021            0
#            Taiwan      66282      Nera Huang    2139       39      52        2021            0
#
#                                                                                          Rank6-10
# MainDate   MarketName  SalesRepID SalesRepName  WeekBooked WeekNum SortOrder FiscalYear
# 2018-09-28 China       1997       Christy Liu   1840       40      1         2019               0
#                        50978      Qian Liu      1840       40      1         2019               0
#                        51244      Cuicui Zhai   1840       40      1         2019               0
#                        53397      Ines Wang     1840       40      1         2019               1
#                        57068      Jeremy Wanghz 1840       40      1         2019               0
# ...                                                                                           ...
# 2021-09-23 Japan       64620      Yumi Ono      2138       38      51        2021               0
#            South Korea 51766      Jimin Kang    2138       38      51        2021               0
#                        57611      Sunjeong Lee  2138       38      51        2021               0
# 2021-09-24 China       57957      Doris Han     2139       39      52        2021               0
#            Taiwan      66282      Nera Huang    2139       39      52        2021               0
#
# [6860 rows x 7 columns]

# %%
df_merged = (df_booked #.set_index(['MainDate',	'MarketName',	'SalesRepID'])
.merge (df_caxed #.set_index(['MainDate',	'MarketName',	'SalesRepID'])
       , left_index=True, right_index=True, how='left', suffixes=('', '_cax'))
.assign(
    # **{col : lambda _df: _df[col].fillna(0).astype('int16') 
            #    for col in ['ProgramDuration_cax', 'EnteredByUser_cax', 'Excel Import_cax', 'Website_cax']}
    ProgramDuration_cax = lambda _df: _df['ProgramDuration_cax'].fillna(0).astype('int16'),
    EnteredByUser_cax = lambda _df: _df['EnteredByUser_cax'].fillna(0).astype('int16'),      
    **{'Excel Import_cax' : lambda _df: _df['Excel Import_cax'].fillna(0).astype('int16')},    
    Website_cax = lambda _df: _df['Website_cax'].fillna(0).astype('int16'),
    **{'Rank1-4_cax' : lambda _df: _df['Rank1-4_cax'].fillna(0).astype('int16')},
    **{'Rank5_cax' : lambda _df: _df['Rank5_cax'].fillna(0).astype('int16')},
    **{'Rank6-10_cax' : lambda _df: _df['Rank6-10_cax'].fillna(0).astype('int16')},   
)
.rename(columns={'Excel Import_cax': 'ExcelImport_cax', 'Excel Import': 'ExcelImport'})
).reset_index()

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20112 entries, 0 to 20111
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   MainDate             20112 non-null  datetime64[ns]
#  1   MarketName           20112 non-null  object
#  2   SalesRepID           20112 non-null  int64
#  3   SalesRepName         20112 non-null  object
#  4   WeekBooked           20112 non-null  int64
#  5   WeekNum              20112 non-null  int64
#  6   SortOrder            20112 non-null  int64
#  7   FiscalYear           20112 non-null  int64
#  8   hasBooked            20112 non-null  int64
#  9   hasCaxed             20112 non-null  int64
#  10  ProgramDuration      20112 non-null  int16
#  11  EnteredByUser        20112 non-null  uint8
#  12  Excel Import         20112 non-null  uint8
#  13  Website              20112 non-null  uint8
#  14  Rank1-4              20112 non-null  uint8
#  15  Rank5                20112 non-null  uint8
#  16  Rank6-10             20112 non-null  uint8
#  17  ProgramDuration_cax  20112 non-null  int16
#  18  EnteredByUser_cax    20112 non-null  int16
#  19  Excel Import_cax     20112 non-null  int16
#  20  Website_cax          20112 non-null  int16
#  21  Rank1-4_cax          20112 non-null  int16
#  22  Rank5_cax            20112 non-null  int16
#  23  Rank6-10_cax         20112 non-null  int16
# dtypes: datetime64[ns](1), int16(8), int64(7), object(2), uint8(6)
# memory usage: 2.0+ MB

# %%
df_merged
# Out:
#         MainDate   MarketName  SalesRepID      SalesRepName  WeekBooked  \
# 0     2018-09-28        China        1997       Christy Liu        1840
# 1     2018-09-28        China       50978          Qian Liu        1840
# 2     2018-09-28        China       51158        Bonnie Yin        1840
# 3     2018-09-28        China       51244       Cuicui Zhai        1840
# 4     2018-09-28        China       53397         Ines Wang        1840
# ...          ...          ...         ...               ...         ...
# 20107 2021-09-29        Japan       64660     Maya Ichikawa        2139
# 20108 2021-09-29        Japan       67577  Ryoichi Yamamoto        2139
# 20109 2021-09-29        Japan       68123        Shu Nozawa        2139
# 20110 2021-09-29  South Korea       57612         Eric Park        2139
# 20111 2021-09-29  South Korea       66705      Yoonjung Cho        2139
#
#        WeekNum  SortOrder  FiscalYear  hasBooked  hasCaxed  ...  Rank1-4  \
# 0           40          1        2019          2         2  ...        2
# 1           40          1        2019          1         1  ...        1
# 2           40          1        2019          2         0  ...        2
# 3           40          1        2019          2         2  ...        2
# 4           40          1        2019          4         3  ...        3
# ...        ...        ...         ...        ...       ...  ...      ...
# 20107       39         52        2021          2         0  ...        2
# 20108       39         52        2021          1         0  ...        1
# 20109       39         52        2021          1         0  ...        1
# 20110       39         52        2021          1         0  ...        1
# 20111       39         52        2021          3         0  ...        2
#
#        Rank5  Rank6-10  ProgramDuration_cax  EnteredByUser_cax  \
# 0          0         0                   18                  1
# 1          0         0                    8                  1
# 2          0         0                    0                  0
# 3          0         0                  105                  2
# 4          0         1                    8                  2
# ...      ...       ...                  ...                ...
# 20107      0         0                    0                  0
# 20108      0         0                    0                  0
# 20109      0         0                    0                  0
# 20110      0         0                    0                  0
# 20111      1         0                    0                  0
#
#        Excel Import_cax  Website_cax  Rank1-4_cax  Rank5_cax  Rank6-10_cax
# 0                     0            1            2          0             0
# 1                     0            0            1          0             0
# 2                     0            0            0          0             0
# 3                     0            0            2          0             0
# 4                     0            1            2          0             1
# ...                 ...          ...          ...        ...           ...
# 20107                 0            0            0          0             0
# 20108                 0            0            0          0             0
# 20109                 0            0            0          0             0
# 20110                 0            0            0          0             0
# 20111                 0            0            0          0             0
#
# [20112 rows x 24 columns]

# %%
df_merged[['Rank5', 'Rank5_cax']].sum()
# Out:
# Rank5        3538
# Rank5_cax     951
# dtype: int64

# %%
df = helper.get_dataframe_from_sqlserver_query('select * from dailysalesdata')
df
# Out:
# /Users/ganesh/Documents/ImportantWork/CleanRepo/BookingSales/helper.py:84: UserWarning:
#
# pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#           id    MainDate   MarketName  SalesRepID      SalesRepName  \
# 0          1  2018-09-28        China        1997       Christy Liu
# 1          2  2018-09-28        China       50978          Qian Liu
# 2          3  2018-09-28        China       51158        Bonnie Yin
# 3          4  2018-09-28        China       51244       Cuicui Zhai
# 4          5  2018-09-28        China       53397         Ines Wang
# ...      ...         ...          ...         ...               ...
# 20107  20108  2021-09-29        Japan       64660     Maya Ichikawa
# 20108  20109  2021-09-29        Japan       67577  Ryoichi Yamamoto
# 20109  20110  2021-09-29        Japan       68123        Shu Nozawa
# 20110  20111  2021-09-29  South Korea       57612         Eric Park
# 20111  20112  2021-09-29  South Korea       66705      Yoonjung Cho
#
#        WeekBooked  WeekNum  SortOrder  FiscalYear  hasBooked  ...  Rank1-4  \
# 0            1840       40          1        2019          2  ...        2
# 1            1840       40          1        2019          1  ...        1
# 2            1840       40          1        2019          2  ...        2
# 3            1840       40          1        2019          2  ...        2
# 4            1840       40          1        2019          4  ...        3
# ...           ...      ...        ...         ...        ...  ...      ...
# 20107        2139       39         52        2021          2  ...        2
# 20108        2139       39         52        2021          1  ...        1
# 20109        2139       39         52        2021          1  ...        1
# 20110        2139       39         52        2021          1  ...        1
# 20111        2139       39         52        2021          3  ...        2
#
#        Rank5  Rank6-10  ProgramDuration_cax  EnteredByUser_cax  \
# 0          0         0                   18                  1
# 1          0         0                    8                  1
# 2          0         0                    0                  0
# 3          0         0                  105                  2
# 4          0         1                    8                  2
# ...      ...       ...                  ...                ...
# 20107      0         0                    0                  0
# 20108      0         0                    0                  0
# 20109      0         0                    0                  0
# 20110      0         0                    0                  0
# 20111      1         0                    0                  0
#
#        ExcelImport_cax  Website_cax  Rank1-4_cax  Rank5_cax  Rank6-10_cax
# 0                    0            1            2          0             0
# 1                    0            0            1          0             0
# 2                    0            0            0          0             0
# 3                    0            0            2          0             0
# 4                    0            1            2          0             1
# ...                ...          ...          ...        ...           ...
# 20107                0            0            0          0             0
# 20108                0            0            0          0             0
# 20109                0            0            0          0             0
# 20110                0            0            0          0             0
# 20111                0            0            0          0             0
#
# [20112 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20112 entries, 0 to 20111
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   20112 non-null  int64
#  1   MainDate             20112 non-null  object
#  2   MarketName           20112 non-null  object
#  3   SalesRepID           20112 non-null  int64
#  4   SalesRepName         20112 non-null  object
#  5   WeekBooked           20112 non-null  int64
#  6   WeekNum              20112 non-null  int64
#  7   SortOrder            20112 non-null  int64
#  8   FiscalYear           20112 non-null  int64
#  9   hasBooked            20112 non-null  int64
#  10  hasCaxed             20112 non-null  int64
#  11  ProgramDuration      20112 non-null  int64
#  12  EnteredByUser        20112 non-null  int64
#  13  ExcelImport          20112 non-null  int64
#  14  Website              20112 non-null  int64
#  15  Rank1-4              20112 non-null  int64
#  16  Rank5                20112 non-null  int64
#  17  Rank6-10             20112 non-null  int64
#  18  ProgramDuration_cax  20112 non-null  int64
#  19  EnteredByUser_cax    20112 non-null  int64
#  20  ExcelImport_cax      20112 non-null  int64
#  21  Website_cax          20112 non-null  int64
#  22  Rank1-4_cax          20112 non-null  int64
#  23  Rank5_cax            20112 non-null  int64
#  24  Rank6-10_cax         20112 non-null  int64
# dtypes: int64(22), object(3)
# memory usage: 3.8+ MB

# %%
df.columns
# Out:
# Index(['id', 'MainDate', 'MarketName', 'SalesRepID', 'SalesRepName',
#        'WeekBooked', 'WeekNum', 'SortOrder', 'FiscalYear', 'hasBooked',
#        'hasCaxed', 'ProgramDuration', 'EnteredByUser', 'ExcelImport',
#        'Website', 'Rank1-4', 'Rank5', 'Rank6-10', 'ProgramDuration_cax',
#        'EnteredByUser_cax', 'ExcelImport_cax', 'Website_cax', 'Rank1-4_cax',
#        'Rank5_cax', 'Rank6-10_cax'],
#       dtype='object')

# %%
df = helper.get_dataframe_from_sqlserver_query('select * from dailysalesdata')

num_cols = ['hasBooked',
       'hasCaxed', 'ProgramDuration', 'EnteredByUser', 'ExcelImport',
       'Website', 'Rank1-4', 'Rank5', 'Rank6-10', 'ProgramDuration_cax',
       'EnteredByUser_cax', 'ExcelImport_cax', 'Website_cax', 'Rank1-4_cax',
       'Rank5_cax', 'Rank6-10_cax']
nonnum = ['MarketName', 'SalesRepID', 'SalesRepName',]

df =(
df.assign(
    MainDate = lambda _df: pd.to_datetime(_df['MainDate']).dt.normalize()
)
.drop('id',axis=1)
)

numeric = num_cols
non_num = nonnum
d = {**{x: 'first' for x in non_num}, **{x: 'sum' for x in numeric}}


# df = df.resample('1D').agg(d)
# Out:
# /Users/ganesh/Documents/ImportantWork/CleanRepo/BookingSales/helper.py:84: UserWarning:
#
# pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.

# %%
df =df.groupby(nonnum).resample('1D', on='MainDate').agg(d).drop(nonnum, axis=1).reset_index()

# %%
df[df['SalesRepName'] == 'Christy Liu']
# Out:
#      MarketName  SalesRepID SalesRepName   MainDate  hasBooked  hasCaxed  \
# 5566      China        1997  Christy Liu 2018-09-28          2         2
# 5567      China        1997  Christy Liu 2018-09-29          2         0
# 5568      China        1997  Christy Liu 2018-09-30          1         0
# 5569      China        1997  Christy Liu 2018-10-01          0         0
# 5570      China        1997  Christy Liu 2018-10-02          0         0
# ...         ...         ...          ...        ...        ...       ...
# 5820      China        1997  Christy Liu 2019-06-09          0         0
# 5821      China        1997  Christy Liu 2019-06-10          0         0
# 5822      China        1997  Christy Liu 2019-06-11          0         0
# 5823      China        1997  Christy Liu 2019-06-12          0         0
# 5824      China        1997  Christy Liu 2019-06-13          1         1
#
#       ProgramDuration  EnteredByUser  ExcelImport  Website  Rank1-4  Rank5  \
# 5566               18              1            0        1        2      0
# 5567                4              2            0        0        2      0
# 5568                2              1            0        0        1      0
# 5569                0              0            0        0        0      0
# 5570                0              0            0        0        0      0
# ...               ...            ...          ...      ...      ...    ...
# 5820                0              0            0        0        0      0
# 5821                0              0            0        0        0      0
# 5822                0              0            0        0        0      0
# 5823                0              0            0        0        0      0
# 5824                2              1            0        0        1      0
#
#       Rank6-10  ProgramDuration_cax  EnteredByUser_cax  ExcelImport_cax  \
# 5566         0                   18                  1                0
# 5567         0                    0                  0                0
# 5568         0                    0                  0                0
# 5569         0                    0                  0                0
# 5570         0                    0                  0                0
# ...        ...                  ...                ...              ...
# 5820         0                    0                  0                0
# 5821         0                    0                  0                0
# 5822         0                    0                  0                0
# 5823         0                    0                  0                0
# 5824         0                    2                  1                0
#
#       Website_cax  Rank1-4_cax  Rank5_cax  Rank6-10_cax
# 5566            1            2          0             0
# 5567            0            0          0             0
# 5568            0            0          0             0
# 5569            0            0          0             0
# 5570            0            0          0             0
# ...           ...          ...        ...           ...
# 5820            0            0          0             0
# 5821            0            0          0             0
# 5822            0            0          0             0
# 5823            0            0          0             0
# 5824            0            1          0             0
#
# [259 rows x 20 columns]

# %%
df[df['SalesRepName'] == 'Christy Liu']
# Out:
#      MarketName  SalesRepID SalesRepName   MainDate  hasBooked  hasCaxed  \
# 5566      China        1997  Christy Liu 2018-09-28          2         2
# 5567      China        1997  Christy Liu 2018-09-29          2         0
# 5568      China        1997  Christy Liu 2018-09-30          1         0
# 5569      China        1997  Christy Liu 2018-10-01          0         0
# 5570      China        1997  Christy Liu 2018-10-02          0         0
# ...         ...         ...          ...        ...        ...       ...
# 5820      China        1997  Christy Liu 2019-06-09          0         0
# 5821      China        1997  Christy Liu 2019-06-10          0         0
# 5822      China        1997  Christy Liu 2019-06-11          0         0
# 5823      China        1997  Christy Liu 2019-06-12          0         0
# 5824      China        1997  Christy Liu 2019-06-13          1         1
#
#       ProgramDuration  EnteredByUser  ExcelImport  Website  Rank1-4  Rank5  \
# 5566               18              1            0        1        2      0
# 5567                4              2            0        0        2      0
# 5568                2              1            0        0        1      0
# 5569                0              0            0        0        0      0
# 5570                0              0            0        0        0      0
# ...               ...            ...          ...      ...      ...    ...
# 5820                0              0            0        0        0      0
# 5821                0              0            0        0        0      0
# 5822                0              0            0        0        0      0
# 5823                0              0            0        0        0      0
# 5824                2              1            0        0        1      0
#
#       Rank6-10  ProgramDuration_cax  EnteredByUser_cax  ExcelImport_cax  \
# 5566         0                   18                  1                0
# 5567         0                    0                  0                0
# 5568         0                    0                  0                0
# 5569         0                    0                  0                0
# 5570         0                    0                  0                0
# ...        ...                  ...                ...              ...
# 5820         0                    0                  0                0
# 5821         0                    0                  0                0
# 5822         0                    0                  0                0
# 5823         0                    0                  0                0
# 5824         0                    2                  1                0
#
#       Website_cax  Rank1-4_cax  Rank5_cax  Rank6-10_cax
# 5566            1            2          0             0
# 5567            0            0          0             0
# 5568            0            0          0             0
# 5569            0            0          0             0
# 5570            0            0          0             0
# ...           ...          ...        ...           ...
# 5820            0            0          0             0
# 5821            0            0          0             0
# 5822            0            0          0             0
# 5823            0            0          0             0
# 5824            0            1          0             0
#
# [259 rows x 20 columns]

# %%
num_cols = ['hasBooked',
       'hasCaxed', 'ProgramDuration', 'EnteredByUser', 'ExcelImport',
       'Website', 'Rank1-4', 'Rank5', 'Rank6-10', 'ProgramDuration_cax',
       'EnteredByUser_cax', 'ExcelImport_cax', 'Website_cax', 'Rank1-4_cax',
       'Rank5_cax', 'Rank6-10_cax']

# %%
(
df.assign(
    MainDate = lambda _df: pd.to_datetime(_df['MainDate']).dt.normalize()
)
.set_index(['MainDate'])
.drop('id',axis=1)
.resample('1D').sum()
)
# Out:
# /var/folders/74/ndv7v28d3078l2cq22t43pkc0000gn/T/ipykernel_5356/4166007795.py:7: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#             SalesRepID  WeekBooked  WeekNum  SortOrder  FiscalYear  hasBooked  \
# MainDate
# 2018-09-28     2924865       99360     2160         54      109026        117
# 2018-09-29     2343031       80960     1760         44       88836         93
# 2018-09-30     2570553       84640     1840         46       92874        127
# 2018-10-01     1388687       47840     1040         26       52494         45
# 2018-10-02     1434931       49680     1080         27       54513         31
# ...                ...         ...      ...        ...         ...        ...
# 2021-09-25      129063        6417      117        156        6063          3
# 2021-09-26        1449        2139       39         52        2021          1
# 2021-09-27      494666       17112      312        416       16168         12
# 2021-09-28      611776       25668      468        624       24252         16
# 2021-09-29      584808       25668      468        624       24252         17
#
#             hasCaxed  ProgramDuration  EnteredByUser  ExcelImport  ...  \
# MainDate                                                           ...
# 2018-09-28        37             1243             80            0  ...
# 2018-09-29        28              922             57            1  ...
# 2018-09-30        47              597            103            1  ...
# 2018-10-01        11              479             28            1  ...
# 2018-10-02         8              439             15            1  ...
# ...              ...              ...            ...          ...  ...
# 2021-09-25         0               36              1            0  ...
# 2021-09-26         0               34              1            0  ...
# 2021-09-27         0              376              4            0  ...
# 2021-09-28         0              273              3            0  ...
# 2021-09-29         0              369             10            0  ...
#
#             Rank1-4  Rank5  Rank6-10  ProgramDuration_cax  EnteredByUser_cax  \
# MainDate
# 2018-09-28      100     11         6                  372                 28
# 2018-09-29       77     10         6                  332                 20
# 2018-09-30      109      8        10                  348                 35
# 2018-10-01       37      3         5                   79                 10
# 2018-10-02       23      7         1                  170                  4
# ...             ...    ...       ...                  ...                ...
# 2021-09-25        3      0         0                    0                  0
# 2021-09-26        1      0         0                    0                  0
# 2021-09-27        9      2         1                    0                  0
# 2021-09-28       14      1         1                    0                  0
# 2021-09-29       15      1         1                    0                  0
#
#             ExcelImport_cax  Website_cax  Rank1-4_cax  Rank5_cax  Rank6-10_cax
# MainDate
# 2018-09-28                0            9           30          6             1
# 2018-09-29                0            8           24          4             0
# 2018-09-30                0           12           37          6             4
# 2018-10-01                0            1           10          0             1
# 2018-10-02                0            4            6          2             0
# ...                     ...          ...          ...        ...           ...
# 2021-09-25                0            0            0          0             0
# 2021-09-26                0            0            0          0             0
# 2021-09-27                0            0            0          0             0
# 2021-09-28                0            0            0          0             0
# 2021-09-29                0            0            0          0             0
#
# [1098 rows x 21 columns]
